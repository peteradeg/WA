# %% [markdown]
# # Main
#
#  THis analysis is for *Victoria*

# %% [markdown]
# ## Filter times

# %%
import matplotlib
matplotlib.use('Agg')

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import ancil_load
import datetime as dt
import ancil_graph
ancil_load=reload(ancil_load)
ancil_graph=reload(ancil_graph)

# %%
# the better way   # data probelm goes from half hours to hours
df_all,price = ancil_load.VIC_lilly_production_price()
price=price.loc[dt.datetime(2017,1,1):dt.datetime(2018,1,1)]
price=price.iloc[::2]
df_all=df_all.iloc[1:,:]

ftimes,fprice = ancil_load.subset_pricefilter(price)
filtered_times = ftimes

# %% [markdown]
# ## Construct plots

# %%
Gen_info=pd.read_excel("/mnt/y/Code/Dev/graph/MacBank/NEM Registration and Exemption List.xls",sheet_name="Generators and Scheduled Loads")
# Read Trading prices info
df_all=pd.read_csv("/mnt/y/Data/Electricity/Average_prices/df_all_VIC_PUBLIC_DVD_TRADING_PRICE.csv",index_col="SETTLEMENTDATE")
df_all=df_all.set_index(pd.DatetimeIndex(df_all.index))

price=df_all["VIC"]
price=price.dropna()

# %%
### 1.0 MST
### 1.1 Analytics
### 2. Wind and temp
### 3. Solar?

# %% [markdown]
# ### 1. MST  NB Note Value factor needs to be passed in a unfiltered price!

# %%
import ancil_graph
import ancil_load
import pandas as pd
ancil_graph=reload(ancil_graph)
ancil_load=reload(ancil_load)

# %%
# Critical step due to time indexing death
df_all.index=pd.date_range(start=dt.datetime(2008,1,1,1),end=dt.datetime(2017,12,31,23),freq="H")

# %%
# STEP1 MST maker

# base file name
basefn="/mnt/y/Data/Weather/ECMWF/Data_R/ml/{0}/{1:02d}/era5_hourly_ml_AUS_{0}{1:02d}.nc"

# loop over all extreme times
for i,tm in enumerate(filtered_times):

    tstart=tm - dt.timedelta(days=1)
    tstart2=tm + dt.timedelta(days=1)

    year  =  tm.year
    month =  tm.month
    day   =  tm.day
    hour  =  tm.hour
    rrp   =  fprice[i]

    # saving plots here
    outpath="/mnt/y/Code/Analysis/graph/Graph_figures/EVENTbased/Victoria_project98/"

    # load generators
#     df_all = pd.read_csv("/mnt/y/Data/Power/ECMWF/lillypond/future_wind.csv")
#     df_all=df_all.drop("time",axis=1)
#     df_all=df_all.drop("Unnamed: 0",axis=1)
#     df_all=df_all.iloc[1:,:]
#     # the 2016-01-2 -> 2016-01-3 missing behaving going to 2016-02-02 instead so hard code dates!
#     df_all.index=pd.date_range(start=dt.datetime(2008,1,1,1),end=dt.datetime(2017,12,31,23),freq="h")

    # load generators (as above)! --- > SA wind

    # Munge creates MST plot
    # works
    #df_delta,df_revenue,G = ancil_load.munge_MST(tstart,tstart2,df_all,fprice,outpath+"MST/size_prod_color_VF_{0}_{1}.png".format(tstart,tstart2))
    # NOt tested
    df_delta,df_revenue,G = ancil_load.munge_MST(tstart,tstart2,df_all,price,outpath+"MST/size_prod_color_VF_{0}_{1}.png".format(tstart,tstart2))

    
    # STEP2 analytics.
    import matplotlib.pyplot as plt
    
    # Calculate dataframe of Analytics
    df_central=ancil_load.munge_analytics_MST(G,tstart)

    import seaborn as sns

#     f=plt.figure(figsize=(20,18))
#     f=sns.lmplot(data=df_central,x="ValueFactor",y="Degree_centrality",hue="node",fit_reg=False)
#     f.savefig(outpath+"Degree_centrality/"+"degree_{0}{1:02d}{2:02d}_{3}_RRP_{4}.png".format(year,month,day,hour,rrp))

    
#     f=plt.figure(figsize=(20,18))
#     f=sns.lmplot(data=df_central,x="ValueFactor",y="CBN1",hue="node",fit_reg=False)
#     f.savefig(outpath+"CBN1/"+"CBN1_{0}{1:02d}{2:02d}_{3}_RRP_{4}.png".format(year,month,day,hour,rrp))


#     f=plt.figure(figsize=(20,18))
#     f=sns.lmplot(data=df_central,x="ValueFactor",y="CBN2",hue="node",fit_reg=False)
#     f.savefig(outpath+"CBN2/"+"CBN2_{0}{1:02d}{2:02d}_{3}_RRP_{4}.png".format(year,month,day,hour,rrp))


#     f=plt.figure(figsize=(20,18))
#     f=sns.lmplot(data=df_central,x="ValueFactor",y="CBN3",hue="node",fit_reg=False)
#     f.savefig(outpath+"CBN3/"+"CBN3_{0}{1:02d}{2:02d}_{3}_RRP_{4}.png".format(year,month,day,hour,rrp))
    
#     f=plt.figure(figsize=(20,18))
#     f=sns.lmplot(data=df_central,x="ValueFactor",y="CBS",hue="node",fit_reg=False)
#     f.savefig(outpath+"CBS/"+"CBS_{0}{1:02d}{2:02d}_{3}_RRP_{4}.png".format(year,month,day,hour,rrp))
    
    
#     # VERY VERY OPTIONAL
    
    u,s,v=np.linalg.svd(df_delta-df_delta.mean(axis=0))
    PC1=u[:,0]
    PC2=u[:,1]
    PC3=u[:,2]
    C1=np.dot(PC1,df_delta)
    C2=np.dot(PC2,df_delta)
    C3=np.dot(PC3,df_delta)
    PCA=pd.DataFrame({"PC1":C1,"PC2":C2,"PC3":C3},index=df_delta.columns)
    PCA["gen"]=PCA.index

    # PCA1 Vs PC2
    f=plt.figure(figsize=(10,9))
    sns.lmplot(data=PCA,x="PC1",y="PC2",hue="gen",fit_reg=False)
    plt.draw()
    f.savefig(outpath+"PCA1/"+"PCA1_{0}{1:02d}{2:02d}_{3}_RRP_{4}.png".format(year,month,day,hour,rrp))

    # PCA1 VC PC3
    f=plt.figure(figsize=(10,9))
    sns.lmplot(data=PCA,x="PC1",y="PC3",hue="gen",fit_reg=False)
    plt.draw()
    f.savefig(outpath+"PCA2/"+"PCA2_{0}{1:02d}{2:02d}_{3}_RRP_{4}.png".format(year,month,day,hour,rrp))
    
    
    plt.clf()
# Out:
# Salt Creek
# MERCER01
# Moorabool
# ARWF1
# Berrimal
# MACARTH1
# Lal Lal (Elaine and Yendon)
# Berrybank
# Yaloak South
# Ryan Corner
# KIATAWF1
# Ferguson
# Yawong
# Woolsthorpe
# Cherry Tree
# Rifle Butts
# Hawkesdale
# OAKLAND1
# Crowlands
# Timboon West
# Mount Gellibrand
# Dundonnell
# Murra Warra
# BALDHWF1
# Mortlake South
# Bulgana
# Stockyard Hill
# Salt Creek
# MERCER01
# Moorabool
# ARWF1
# Berrimal
# MACARTH1
# Lal Lal (Elaine and Yendon)
# Berrybank
# Yaloak South
# Ryan Corner
# KIATAWF1
# Ferguson
# Yawong
# Woolsthorpe
# Cherry Tree
# Rifle Butts
# Hawkesdale
# OAKLAND1
# Crowlands
# Timboon West
# Mount Gellibrand
# Dundonnell
# Murra Warra
# BALDHWF1
# Mortlake South
# Bulgana
# Stockyard Hill
# Salt Creek
# MERCER01
# Moorabool
# ARWF1
# Berrimal
# MACARTH1
# Lal Lal (Elaine and Yendon)
# Berrybank
# Yaloak South
# Ryan Corner
# KIATAWF1
# Ferguson
# Yawong
# Woolsthorpe
# Cherry Tree
# Rifle Butts
# Hawkesdale
# OAKLAND1
# Crowlands
# Timboon West
# Mount Gellibrand
# Dundonnell
# Murra Warra
# BALDHWF1
# Mortlake South
# Bulgana
# Stockyard Hill
# Salt Creek
# MERCER01
# Moorabool
# ARWF1
# Berrimal
# MACARTH1
# Lal Lal (Elaine and Yendon)
# Berrybank
# Yaloak South
# Ryan Corner
# KIATAWF1
# Ferguson
# Yawong
# Woolsthorpe
# Cherry Tree
# Rifle Butts
# Hawkesdale
# OAKLAND1
# Crowlands
# Timboon West
# Mount Gellibrand
# Dundonnell
# Murra Warra
# BALDHWF1
# Mortlake South
# Bulgana
# Stockyard Hill
# Salt Creek
# MERCER01
# Moorabool
# ARWF1
# Berrimal
# MACARTH1
# Lal Lal (Elaine and Yendon)
# Berrybank
# Yaloak South
# Ryan Corner
# KIATAWF1
# Ferguson
# Yawong
# Woolsthorpe
# Cherry Tree
# Rifle Butts
# Hawkesdale
# OAKLAND1
# Crowlands
# Timboon West
# Mount Gellibrand
# Dundonnell
# Murra Warra
# BALDHWF1
# Mortlake South
# Bulgana
# Stockyard Hill
# Salt Creek
# MERCER01
# Moorabool
# ARWF1
# Berrimal
# MACARTH1
# Lal Lal (Elaine and Yendon)
# Berrybank
# Yaloak South
# Ryan Corner
# KIATAWF1
# Ferguson
# Yawong
# Woolsthorpe
# Cherry Tree
# Rifle Butts
# Hawkesdale
# OAKLAND1
# Crowlands
# Timboon West
# Mount Gellibrand
# Dundonnell
# Murra Warra
# BALDHWF1
# Mortlake South
# Bulgana
# Stockyard Hill
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-b5dc494a2adb> in <module>()
#      33     #df_delta,df_revenue,G = ancil_load.munge_MST(tstart,tstart2,df_all,fprice,outpath+"MST/size_prod_color_VF_{0}_{1}.png".format(tstart,tstart2))
#      34     # NOt tested
# ---> 35     df_delta,df_revenue,G = ancil_load.munge_MST(tstart,tstart2,df_all,price,outpath+"MST/size_prod_color_VF_{0}_{1}.png".format(tstart,tstart2))
#      36
#      37
#
# /mnt/y/Code/Analysis/graph/ancil_load.pyc in munge_MST(tstart, tstart2, df_all, price, out)
#     304     df_delta = df_all.loc[tstart:tstart2]
#     305     df_revenue=df_delta.mul(price.loc[df_delta.index],axis=0)
# --> 306     G=ancil_graph.makeG1(df_delta,df_revenue,price.loc[df_delta.index],out,"SA")
#     307
#     308     return df_delta,df_revenue,G
#
# /mnt/y/Code/Analysis/graph/ancil_graph.pyc in makeG1(df_size, df_attr, price, path, state)
#     445         G=GfromAEMO(df_size)
#     446     elif state=="SA":
# --> 447         G,X=GfromIntersect(df_size)
#     448     else:
#     449         G=0
#
# /mnt/y/Code/Analysis/graph/ancil_graph.pyc in GfromIntersect(df_all_ancil)
#     122             # Intersect i and j
#     123             a=df_all_ancil[i].dropna()
# --> 124             b=df_all_ancil[j].dropna()
#     125             setij=a.index.intersection(b.index)
#     126
#
# /home/peterad/.local/lib/python2.7/site-packages/pandas/core/series.pyc in dropna(self, axis, inplace, **kwargs)
#    2989
#    2990         if self._can_hold_na:
# -> 2991             result = remove_na_arraylike(self)
#    2992             if inplace:
#    2993                 self._update_inplace(result)
#
# /home/peterad/.local/lib/python2.7/site-packages/pandas/core/dtypes/missing.pyc in remove_na_arraylike(arr)
#     397     Return array-like containing only true/non-NaN values, possibly empty.
#     398     """
# --> 399     return arr[notna(lib.values_from_object(arr))]
#
# /home/peterad/.local/lib/python2.7/site-packages/pandas/core/series.pyc in __getitem__(self, key)
#     662             key = check_bool_indexer(self.index, key)
#     663
# --> 664         return self._get_with(key)
#     665
#     666     def _get_with(self, key):
#
# /home/peterad/.local/lib/python2.7/site-packages/pandas/core/series.pyc in _get_with(self, key)
#     698                     return self._get_values(key)
#     699             elif key_type == 'boolean':
# --> 700                 return self._get_values(key)
#     701             else:
#     702                 try:
#
# /home/peterad/.local/lib/python2.7/site-packages/pandas/core/series.pyc in _get_values(self, indexer)
#     729     def _get_values(self, indexer):
#     730         try:
# --> 731             return self._constructor(self._data.get_slice(indexer),
#     732                                      fastpath=True).__finalize__(self)
#     733         except Exception:
#
# /home/peterad/.local/lib/python2.7/site-packages/pandas/core/internals.pyc in get_slice(self, slobj, axis)
#    4466
#    4467         return self.__class__(self._block._slice(slobj),
# -> 4468                               self.index[slobj], fastpath=True)
#    4469
#    4470     @property
#
# /home/peterad/.local/lib/python2.7/site-packages/pandas/core/indexes/datetimelike.pyc in __getitem__(self, key)
#     287                 freq = None
#     288                 if isinstance(key, slice):
# --> 289                     if self.freq is not None and key.step is not None:
#     290                         freq = key.step * self.freq
#     291                     else:
#
# KeyboardInterrupt:

# %%
sns.lmplot(data=PCA,x="PC1",y="PC2",hue="gen",fit_reg=False)

# %%
df_central.mean(axis=0)
# Out:
# Degree_centrality      0.074074
# Eigencentrality        0.149990
# katz                   0.191605
# Pagerank               0.037037
# Closeness              0.192303
# Clustering             0.000000
# ValueFactor          115.869899
# Generation            49.110113
# CBN1                   0.560437
# CBN2                   0.036693
# CBN3                   1.768571
# CBS                    0.745420
# dtype: float64

# %%
import seaborn as sns
# Degree_centrlaity
a=sns.lmplot(data=df_central,x="ValueFactor",y="Degree_centrality",hue="node",fit_reg=False)
#df.plot.bar(x="node",y="katz")

# %% [markdown]
# ### 2. Wind and TEMP

# %%
import matplotlib
matplotlib.use('Agg')

import numpy as np
import pandas as pd
import seaborn as sns
import ancil_load
import datetime as dt
import ancil_graph
ancil_load=reload(ancil_load)
ancil_graph=reload(ancil_graph)



# wind base name

df_all,price = ancil_load.VIC_lilly_production_price()
price=price.loc[dt.datetime(2017,1,1):dt.datetime(2018,1,1)]
price=price.iloc[::2]
df_all=df_all.iloc[1:,:]

ftimes,fprice = ancil_load.subset_pricefilter(price)
filtered_times = ftimes


ancil_load=reload(ancil_load)
basefn="/mnt/y/Data/Weather/ECMWF/Data_R/ml/{0}/{1:02d}/era5_hourly_ml_AUS_{0}{1:02d}.nc"


for i,tm in enumerate(ftimes):
    #ancil_load.Cartopy_Earth_wind(tm,"t",price[i],basefn)
    ancil_load.Cartopy_Earth_VIC(tm,"t",price[i],basefn)

# %% [markdown]
# ### 3. TEMP

# %% [markdown]
# ## PPTX

# %%
from netCDF4 import Dataset, MFDataset, num2date
import matplotlib.pylab as plt
import numpy as np
from matplotlib import cm
import cartopy.crs as ccrs

import sys
import os
from cartopy.util import add_cyclic_point

# The hard part!
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-5-cd2028b585a3> in <module>()
#       3 import numpy as np
#       4 from matplotlib import cm
# ----> 5 import cartopy.crs as ccrs
#       6
#       7 import sys
#
# /mnt/y/Code/Analysis/graph/powerdeck/cartopy.py in <module>()
#       3
#       4 from datetime import datetime
# ----> 5 import cartopy.crs as ccrs
#       6 import cartopy.feature as cfeature
#       7 import matplotlib.pyplot as plt
#
# ImportError: No module named crs

# %%
x35*8*4*48
# Out:
# 53760
