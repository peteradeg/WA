# %%
# %matplotlib notebook

# %%
import pandas as pd
import numpy as np
import ancil_load
import datetime as dt
ancil_load = reload(ancil_load)
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_all_ancil,price = ancil_load.SA_production_price()
df_all_ancil["index"]=df_all_ancil.index
df_all_ancil=df_all_ancil.drop_duplicates("index")
df_all_ancil=df_all_ancil.drop("index",axis=1)
df_all_ancil=df_all_ancil.fillna(0)

# price=pd.DataFrame(price)
# price["index"]=price.index
# price=price.drop_duplicates("index")
# price=price.drop("index",axis=1)
# price=pd.Series(price)

df=df_all_ancil.loc[dt.datetime(2017,1,1):dt.datetime(2017,,1)]

# %%
# U is the eigenvectors we care about

# Should this be capacity or not?
u,s,v=np.linalg.svd(df-df.mean(axis=0))

PC1=v[:,0]
PC2=v[:,1]
PC3=v[:,2]

C1=np.dot(df,PC1)
C2=np.dot(df,PC2)
C3=np.dot(df,PC3)

PCA=pd.DataFrame({"PC1":C1,"PC2":C2,"PC3":C3},index=df.index)
PCA["gen"]=PCA.index
PCA["month"]=np.array(np.array(PCA.index.month))
PCA["day"]=np.array(np.array(PCA.index.day))

import seaborn as sns

# PCA1 Vs PC2
#sns.lmplot(data=PCA,x="PC1",y="PC2",hue="gen",fit_reg=False)
import matplotlib.pyplot as plt
#fig, ax = plt.subplots()
sns.lmplot(data=PCA,x="PC1",y="PC2",fit_reg=False)

# Looking at timeseries underneath
#df[["SNOWNTH1","HDWF3","CLEMGPWF","LKBONNY2"]].plot()
# Out:
# <img src="data:image/png;base64,..." width="499.9999925494195">
# Error in callback <function post_execute at 0x7ff0e3246de8> (for post_execute):
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/peterad/.local/lib/python2.7/site-packages/matplotlib/pyplot.pyc in post_execute()
#     147             def post_execute():
#     148                 if matplotlib.is_interactive():
# --> 149                     draw_all()
#     150
#     151             # IPython >= 2
#
# /home/peterad/.local/lib/python2.7/site-packages/matplotlib/_pylab_helpers.pyc in draw_all(cls, force)
#     134         for f_mgr in cls.get_all_fig_managers():
#     135             if force or f_mgr.canvas.figure.stale:
# --> 136                 f_mgr.canvas.draw_idle()
#     137
#     138 atexit.register(Gcf.destroy_all)
#
# ...

# %%
# U is the eigenvectors we care about
u,s,v=np.linalg.svd(df)

PC1=v[:,0]
PC2=v[:,1]
PC3=v[:,2]

C1=np.dot(df,PC1)
C2=np.dot(df,PC2)
C3=np.dot(df,PC3)

PCA=pd.DataFrame({"PC1":C1,"PC2":C2,"PC3":C3},index=df.index)
PCA["gen"]=PCA.index
PCA["month"]=np.array(np.array(PCA.index.month))
PCA["day"]=np.array(np.array(PCA.index.day))

import seaborn as sns

# PCA1 Vs PC2
#sns.lmplot(data=PCA,x="PC1",y="PC2",hue="gen",fit_reg=False)
import matplotlib.pyplot as plt
#fig, ax = plt.subplots()
sns.lmplot(data=PCA,x="PC1",y="PC2",fit_reg=False,col="month")

# Looking at timeseries underneath
#df[["SNOWNTH1","HDWF3","CLEMGPWF","LKBONNY2"]].plot()
# Out:
# <img src="data:image/png;base64,..." width="2499.9999627470975">

# %%
def mkdir_p(mypath):
    '''Creates a directory. equivalent to using mkdir -p on the command line'''

    from errno import EEXIST
    from os import makedirs,path

    try:
        makedirs(mypath)
    except OSError as exc: # Python >2.5
        if exc.errno == EEXIST and path.isdir(mypath):
            pass
        else: raise

# %% [markdown]
# ### Only season

# %%
df.columns
# Out:
# Index([u'HALLWF1', u'SNOWNTH1', u'HALLWF2', u'WATERLWF', u'BLUFF1',
#        u'LKBONNY3', u'LKBONNY2', u'NBHWF1', u'CLEMGPWF', u'HDWF1', u'SNOWTWN1',
#        u'HDWF2', u'HDWF3', u'SNOWSTH1'],
#       dtype='object')

# %%
# loop over sites
import datetime 
threshold = .8
site = "LKBONNY2"

outpath="/mnt/y/Code/Analysis/graph/Graph_figures/CBN_testing_filter/South Australia/Production/"



# # U is the eigenvectors we care about
# df=df_all_ancil.loc[dt.datetime(2017,1,1):dt.datetime(2017,,1)]

# # Should this be capacity or not?
# u,s,v=np.linalg.svd(df-df.mean(axis=0))

# PC1=v[:,0]
# PC2=v[:,1]
# PC3=v[:,2]

# C1=np.dot(df,PC1)
# C2=np.dot(df,PC2)
# C3=np.dot(df,PC3)

# PCA=pd.DataFrame({"PC1":C1,"PC2":C2,"PC3":C3},index=df.index)
# PCA["gen"]=PCA.index
# PCA["month"]=np.array(np.array(PCA.index.month))
# PCA["day"]=np.array(np.array(PCA.index.day))

# import seaborn as sns

# # PCA1 Vs PC2
# #sns.lmplot(data=PCA,x="PC1",y="PC2",hue="gen",fit_reg=False)
# import matplotlib.pyplot as plt
# #fig, ax = plt.subplots()
# sns.lmplot(data=PCA,x="PC1",y="PC2",fit_reg=False)

# # Looking at timeseries underneath
# #df[["SNOWNTH1","HDWF3","CLEMGPWF","LKBONNY2"]].plot()







# Capcaity of state
capacity = df.max(axis=0).sum()

for i,site in enumerate(df.columns):
    mkdir_p(outpath+"PCA_coloured")

    # Filter for capacity above threshold
    df_subset=df[df[site]/(df[site].max())> threshold]

    # Filter again for state capacity
    state_cap=df_subset.sum(axis=1)/capacity>.5
    state_cap=df_subset.loc[~state_cap]

    # Capacity of state
    df_subset=df_subset/df_subset.max(axis=0)

    # colour PCA
    PCA[site] = "Above"
    PCA.loc[df_subset.index,site]="Below"
    
    
    


    f=plt.figure(figsize=(10,9))
    f=sns.lmplot(data=PCA,x="PC1",y="PC2",col="month",line_kws={'color':"blue"},fit_reg=False,hue=site)
    #f.ax.title=plt.title("hey")
    f.savefig(outpath+"/PCA_coloured/"+site)
    
    # timeseries plot
    title_string="{0} is above {1} = {2}; Of these state>.5 {3}/{2}".format(site,threshold,df_subset.shape[0],state_cap.shape[0])
    f=plt.figure(figsize=(10,9))
    f=df_subset.loc[state_cap.index].plot(marker="o")
    plt.title(title_string)
    plt.savefig(outpath+"/timeseries/"+site)  
    

    plt.clf()

    
# The eigen vecotr plot
xpos=np.arange(len(df.columns))
plt.bar(xpos,PC1)
plt.xticks(xpos,df.columns)
plt.xticks(rotation="45")
plt.title("eig1 {0:2.3f}".format(s[0]))
plt.savefig(outpath+"eig1.png")
plt.clf()
# The eigen vecotr plot
xpos=np.arange(len(df.columns))
plt.bar(xpos,PC2)
plt.xticks(xpos,df.columns)
plt.xticks(rotation="45")
plt.title("eig2 {0:2.3f}".format(s[1]))
plt.savefig(outpath+"eig2.png")
plt.clf()
# The eigen vecotr plot
xpos=np.arange(len(df.columns))
plt.bar(xpos,PC3)
plt.xticks(xpos,df.columns)
plt.xticks(rotation="45")
plt.title("eig3 {0:2.3f}".format(s[2]))
plt.savefig(outpath+"eig3.png")
plt.clf()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-913eaa35f87a> in <module>()
#      15
#      16     # Filter for capacity above threshold
# ---> 17     df_subset=df[df[site]/(df[site].max())> threshold]
#      18
#      19     # Filter again for state capacity
#
# /home/peterad/.local/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# /home/peterad/.local/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
# ...

# %%
# The eigen vecotr plot
xpos=np.arange(len(df.columns))
plt.bar(xpos,PC1)
plt.xticks(xpos,df.columns)
plt.xticks(rotation="45")
plt.title("eig1 {0:2.3f}".format(s[0]))
plt.savefig(outpath+"eig1.png")
plt.clf()
# The eigen vecotr plot
xpos=np.arange(len(df.columns))
plt.bar(xpos,PC2)
plt.xticks(xpos,df.columns)
plt.xticks(rotation="45")
plt.title("eig2 {0:2.3f}".format(s[1]))
plt.savefig(outpath+"eig2.png")
plt.clf()
# The eigen vecotr plot
xpos=np.arange(len(df.columns))
plt.bar(xpos,PC3)
plt.xticks(xpos,df.columns)
plt.xticks(rotation="45")
plt.title("eig3 {0:2.3f}".format(s[2]))
plt.savefig(outpath+"eig3.png")
plt.clf()

# %%
df.index
# Out:
# DatetimeIndex(['2017-01-01 00:00:00', '2017-01-01 00:30:00',
#                '2017-01-01 01:00:00', '2017-01-01 01:30:00',
#                '2017-01-01 02:00:00', '2017-01-01 02:30:00',
#                '2017-01-01 03:00:00', '2017-01-01 03:30:00',
#                '2017-01-01 04:00:00', '2017-01-01 04:30:00',
#                ...
#                '2017-04-30 19:30:00', '2017-04-30 20:00:00',
#                '2017-04-30 20:30:00', '2017-04-30 21:00:00',
#                '2017-04-30 21:30:00', '2017-04-30 22:00:00',
#                '2017-04-30 22:30:00', '2017-04-30 23:00:00',
#                '2017-04-30 23:30:00', '2017-05-01 00:00:00'],
#               dtype='datetime64[ns]', name=u'SETTLEMENTDATE', length=5761, freq=None)

# %%
site
# Out:
# 'S'

# %%
outpath
# Out:
# '/mnt/y/Code/Analysis/graph/Graph_figures/CBN_testing_filter/South Australia/Production/'

# %%
tstart=datetime.datetime(2017,1,1)
tstart2=datetime.datetime(2018,1,1)

df_delta,df_revenue,G = ancil_load.munge_MST(tstart,tstart2,df,price.loc[df.index],outpath+site)


# STEP2 analytics.
import matplotlib.pyplot as plt

# Calculate dataframe of Analytics
df_central=ancil_load.munge_analytics_MST(G,tstart)

import seaborn as sns

f=plt.figure(figsize=(20,18))
f=sns.lmplot(data=df_central,x="ValueFactor",y="Degree_centrality",hue="node",fit_reg=False)
f.savefig(outpath+"Degree_centrality/"+"degree"+site)


f=plt.figure(figsize=(20,18))
f=sns.lmplot(data=df_central,x="ValueFactor",y="CBN1",hue="node",fit_reg=False)
f.savefig(outpath+"CBN1/"+"CBN1"+site)


f=plt.figure(figsize=(20,18))
f=sns.lmplot(data=df_central,x="ValueFactor",y="CBN2",hue="node",fit_reg=False)
f.savefig(outpath+"CBN2/"+"CBN2"+site)


f=plt.figure(figsize=(20,18))
f=sns.lmplot(data=df_central,x="ValueFactor",y="CBN3",hue="node",fit_reg=False)
f.savefig(outpath+"CBN3/"+"CBN3"+site)

f=plt.figure(figsize=(20,18))
f=sns.lmplot(data=df_central,x="ValueFactor",y="CBS",hue="node",fit_reg=False)
f.savefig(outpath+"CBS/"+"CBS"+site)
# Out:
# /home/peterad/.local/lib/python2.7/site-packages/numpy/lib/function_base.py:3183: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# /home/peterad/.local/lib/python2.7/site-packages/numpy/lib/function_base.py:3184: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]
# HALLWF1
# SNOWNTH1
# HALLWF2
# WATERLWF
# LKBONNY3
# LKBONNY2
# BLUFF1
# NBHWF1
# HDWF1
# SNOWTWN1
# HDWF2
# SNOWSTH1
# CLEMGPWF
# <img src="data:image/png;base64,..." width="1999.999970197678">
# <img src="data:image/png;base64,..." width="1999.999970197678">
# <img src="data:image/png;base64,..." width="634.9999905377628">
# <img src="data:image/png;base64,..." width="1999.999970197678">
# <img src="data:image/png;base64,..." width="634.9999905377628">
# <img src="data:image/png;base64,..." width="1999.999970197678">
# <img src="data:image/png;base64,..." width="634.9999905377628">
# <img src="data:image/png;base64,..." width="1999.999970197678">
# ...

# %%
"eig1 {0:2.2f}".format(.0983)
# Out:
# 'eig1 0.10'
