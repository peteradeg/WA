# %% [markdown]
# # Main
#
#  THis analysis is for *South Australia*

# %% [markdown]
# ## Filter times

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import ancil_load
ancil_load=reload(ancil_load)

# %%
# the better way
df_all,price = ancil_load.SA_production_price()
price=price.loc[dt.datetime(2017,1,1):dt.datetime(2018,1,1)]
price=price.iloc[::2]
df_all=df_all.iloc[1::2]
ftimes,fprice = ancil_load.subset_pricefilter(price)
filtered_times = ftimes

# %% [markdown]
# ## Construct plots

# %%
### 1.0 MST
### 1.1 Analytics
### 2. Wind and temp
### 3. Solar?

# %% [markdown]
# ### 1. MST  NB Note Value factor needs to be passed in a unfiltered price!

# %%
df_delta=df_all.loc[tstart:tstart2]

# %%
df_delta
# Out:
#                      HALLWF1  SNOWNTH1  HALLWF2  WATERLWF  BLUFF1  LKBONNY3  \
# SETTLEMENTDATE
# 2017-01-03 16:00:00    23.85    114.25    27.67     26.74   11.79     27.97
# 2017-01-03 17:00:00    26.44    118.71    29.84     37.54   12.39     26.56
# 2017-01-03 18:00:00    32.24    124.79    30.58     39.90   18.77     26.35
# 2017-01-03 19:00:00    37.67    128.02    39.25     42.41    6.99     19.92
# 2017-01-03 20:00:00    39.07    124.34    39.13     33.06    3.71     18.36
# 2017-01-03 21:00:00    31.31    124.37    47.66     25.46    2.11     24.38
# 2017-01-03 22:00:00    44.98    122.69    49.43     38.79    8.58     17.55
# 2017-01-03 23:00:00    59.51    116.76    54.14     45.05    4.67     11.23
# 2017-01-04 00:00:00    70.81    120.72    60.04     53.18   12.73     16.68
# 2017-01-04 01:00:00    73.85     87.21    62.34     70.34    8.73     18.69
# 2017-01-04 02:00:00    63.97     69.53    61.21     60.80    6.45     14.57
# 2017-01-04 03:00:00    58.56     62.73    58.15     56.50    6.48      9.84
# 2017-01-04 04:00:00    60.49     82.00    47.20     49.69    8.09     10.85
# 2017-01-04 05:00:00    40.49     83.22    36.34     49.88    4.11     10.67
# 2017-01-04 06:00:00    28.43     71.83    28.68     49.86    0.03      9.96
# 2017-01-04 07:00:00    31.18     46.25    32.17     57.79    2.08      9.95
# 2017-01-04 08:00:00    20.65     27.36    14.83     42.59    0.39     12.73
# 2017-01-04 09:00:00    15.35     16.58    14.69     22.11    1.65     14.06
# 2017-01-04 10:00:00    11.02      8.44     8.78     14.34    0.54     10.75
# 2017-01-04 11:00:00     3.45      2.07     6.49     16.12    2.34      8.76
# 2017-01-04 12:00:00     0.00      0.44     3.91     17.94    0.07      5.50
# 2017-01-04 13:00:00     0.00      0.29     1.81      9.61    0.04      1.92
# 2017-01-04 14:00:00     0.64      4.42     4.49      3.81    0.14      4.76
# 2017-01-04 15:00:00     0.26     35.94     5.65      8.84    0.60      6.76
# 2017-01-04 16:00:00     8.66     57.12     8.85     13.29    1.81      7.45
# 2017-01-04 17:00:00    12.22     76.50    10.24     12.02    4.59      8.74
# 2017-01-04 18:00:00    15.08     91.12    14.93     19.51    3.25     10.81
# 2017-01-04 19:00:00    19.23    120.10    22.27     46.94    5.48      8.23
# 2017-01-04 20:00:00    31.51    138.95    24.86     53.26    8.79     10.74
# 2017-12-31 07:30:00    107.26
# 2017-12-31 08:30:00    120.33
# 2017-12-31 09:30:00    127.49
# 2017-12-31 10:30:00    172.13
# 2017-12-31 11:30:00    129.46
# 2017-12-31 12:30:00    131.46
# 2017-12-31 13:30:00    244.10
# 2017-12-31 14:30:00    137.44
# 2017-12-31 15:30:00    111.32
# 2017-12-31 16:30:00    105.13
# 2017-12-31 17:30:00     99.36
# 2017-12-31 18:30:00    109.57
# 2017-12-31 19:30:00     95.19
# 2017-12-31 20:30:00    101.04
# 2017-12-31 21:30:00    105.44
# 2017-12-31 22:30:00    103.59
# 2017-12-31 23:30:00    112.75
# Name: SA, Length: 70127, dtype: float64

# %%
df_delta.index
# Out:
# DatetimeIndex(['2017-01-03 16:00:00', '2017-01-03 17:00:00',
#                '2017-01-03 18:00:00', '2017-01-03 19:00:00',
#                '2017-01-03 20:00:00', '2017-01-03 21:00:00',
#                '2017-01-03 22:00:00', '2017-01-03 23:00:00',
#                '2017-01-04 00:00:00', '2017-01-04 01:00:00',
#                '2017-01-04 02:00:00', '2017-01-04 03:00:00',
#                '2017-01-04 04:00:00', '2017-01-04 05:00:00',
#                '2017-01-04 06:00:00', '2017-01-04 07:00:00',
#                '2017-01-04 08:00:00', '2017-01-04 09:00:00',
#                '2017-01-04 10:00:00', '2017-01-04 11:00:00',
#                '2017-01-04 12:00:00', '2017-01-04 13:00:00',
#                '2017-01-04 14:00:00', '2017-01-04 15:00:00',
#                '2017-01-04 16:00:00', '2017-01-04 17:00:00',
#                '2017-01-04 18:00:00', '2017-01-04 19:00:00',
#                '2017-01-04 20:00:00', '2017-01-04 21:00:00',
#                '2017-01-04 22:00:00', '2017-01-04 23:00:00',
#                '2017-01-05 00:00:00', '2017-01-05 01:00:00',
#                '2017-01-05 02:00:00', '2017-01-05 03:00:00',
#                '2017-01-05 04:00:00', '2017-01-05 05:00:00',
#                '2017-01-05 06:00:00', '2017-01-05 07:00:00',
#                '2017-01-05 08:00:00', '2017-01-05 09:00:00',
#                '2017-01-05 10:00:00', '2017-01-05 11:00:00',
#                '2017-01-05 12:00:00', '2017-01-05 13:00:00',
#                '2017-01-05 14:00:00', '2017-01-05 15:00:00'],
#               dtype='datetime64[ns]', name=u'SETTLEMENTDATE', freq=None)

# %%
price
# Out:
# SETTLEMENTDATE
# 2010-01-01 01:00:00     19.95
# 2010-01-01 02:00:00     17.48
# 2010-01-01 03:00:00     15.12
# 2010-01-01 04:00:00     11.35
# 2010-01-01 05:00:00     12.93
# 2010-01-01 06:00:00     12.86
# 2010-01-01 07:00:00     14.20
# 2010-01-01 08:00:00     16.84
# 2010-01-01 09:00:00     18.35
# 2010-01-01 10:00:00     19.52
# 2010-01-01 11:00:00     19.67
# 2010-01-01 12:00:00     20.07
# 2010-01-01 13:00:00     19.60
# 2010-01-01 14:00:00     18.94
# 2010-01-01 15:00:00     19.04
# 2010-01-01 16:00:00     19.52
# 2010-01-01 17:00:00     21.01
# 2010-01-01 18:00:00     22.38
# 2010-01-01 19:00:00     20.09
# 2010-01-01 20:00:00     19.41
# 2010-01-01 21:00:00     19.44
# 2010-01-01 22:00:00     17.66
# 2010-01-01 23:00:00     10.32
# 2010-01-02 00:00:00     17.53
# 2010-01-02 01:00:00     11.69
# 2010-01-02 02:00:00     11.84
# 2010-01-02 03:00:00      9.64
# 2010-01-02 04:00:00      8.63
# 2010-01-02 05:00:00      5.68
# 2010-01-02 06:00:00      9.07
#                         ...
# 2017-12-30 18:30:00     93.78
# 2017-12-30 19:30:00     71.69
# 2017-12-30 20:30:00     98.04
# 2017-12-30 21:30:00    101.05
# 2017-12-30 22:30:00     96.24
# 2017-12-30 23:30:00     65.42
# 2017-12-31 00:30:00     83.65
# 2017-12-31 01:30:00     86.43
# 2017-12-31 02:30:00     84.72
# 2017-12-31 03:30:00     68.90
# 2017-12-31 04:30:00     80.47
# 2017-12-31 05:30:00    108.11
# 2017-12-31 06:30:00     83.93
# 2017-12-31 07:30:00    107.26
# 2017-12-31 08:30:00    120.33
# 2017-12-31 09:30:00    127.49
# 2017-12-31 10:30:00    172.13
# 2017-12-31 11:30:00    129.46
# 2017-12-31 12:30:00    131.46
# 2017-12-31 13:30:00    244.10
# 2017-12-31 14:30:00    137.44
# 2017-12-31 15:30:00    111.32
# 2017-12-31 16:30:00    105.13
# 2017-12-31 17:30:00     99.36
# 2017-12-31 18:30:00    109.57
# 2017-12-31 19:30:00     95.19
# 2017-12-31 20:30:00    101.04
# 2017-12-31 21:30:00    105.44
# 2017-12-31 22:30:00    103.59
# 2017-12-31 23:30:00    112.75
# Name: SA, Length: 70127, dtype: float64

# %%
price.loc[df_delta.index]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-106-a106a5f655b4> in <module>()
# ----> 1 price.loc[df_delta.index]
#
# /home/peterad/.local/lib/python2.7/site-packages/pandas/core/indexing.pyc in __getitem__(self, key)
#    1371
#    1372             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1373             return self._getitem_axis(maybe_callable, axis=axis)
#    1374
#    1375     def _is_scalar_access(self, key):
#
# /home/peterad/.local/lib/python2.7/site-packages/pandas/core/indexing.pyc in _getitem_axis(self, key, axis)
#    1614                     raise ValueError('Cannot index with multidimensional key')
#    1615
# -> 1616                 return self._getitem_iterable(key, axis=axis)
#    1617
#    1618             # nested tuple slicing
#
# /home/peterad/.local/lib/python2.7/site-packages/pandas/core/indexing.pyc in _getitem_iterable(self, key, axis)
#    1113
#    1114         if self._should_validate_iterable(axis):
# -> 1115             self._has_valid_type(key, axis)
#    1116
#    1117         labels = self.obj._get_axis(axis)
#
# /home/peterad/.local/lib/python2.7/site-packages/pandas/core/indexing.pyc in _has_valid_type(self, key, axis)
#    1470                         raise KeyError(
#    1471                             u"None of [{key}] are in the [{axis}]".format(
# -> 1472                                 key=key, axis=self.obj._get_axis_name(axis)))
#    1473                     else:
#    1474
#
# KeyError: u"None of [DatetimeIndex(['2017-01-03 16:00:00', '2017-01-03 17:00:00',\n               '2017-01-03 18:00:00', '2017-01-03 19:00:00',\n               '2017-01-03 20:00:00', '2017-01-03 21:00:00',\n               '2017-01-03 22:00:00', '2017-01-03 23:00:00',\n               '2017-01-04 00:00:00', '2017-01-04 01:00:00',\n               '2017-01-04 02:00:00', '2017-01-04 03:00:00',\n               '2017-01-04 04:00:00', '2017-01-04 05:00:00',\n               '2017-01-04 06:00:00', '2017-01-04 07:00:00',\n               '2017-01-04 08:00:00', '2017-01-04 09:00:00',\n               '2017-01-04 10:00:00', '2017-01-04 11:00:00',\n               '2017-01-04 12:00:00', '2017-01-04 13:00:00',\n               '2017-01-04 14:00:00', '2017-01-04 15:00:00',\n               '2017-01-04 16:00:00', '2017-01-04 17:00:00',\n               '2017-01-04 18:00:00', '2017-01-04 19:00:00',\n               '2017-01-04 20:00:00', '2017-01-04 21:00:00',\n               '2017-01-04 22:00:00', '2017-01-04 23:00:00',\n               '2017-01-05 00:00:00', '2017-01-05 01:00:00',\n               '2017-01-05 02:00:00', '2017-01-05 03:00:00',\n               '2017-01-05 04:00:00', '2017-01-05 05:00:00',\n               '2017-01-05 06:00:00', '2017-01-05 07:00:00',\n               '2017-01-05 08:00:00', '2017-01-05 09:00:00',\n               '2017-01-05 10:00:00', '2017-01-05 11:00:00',\n               '2017-01-05 12:00:00', '2017-01-05 13:00:00',\n               '2017-01-05 14:00:00', '2017-01-05 15:00:00'],\n              dtype='datetime64[ns]', name=u'SETTLEMENTDATE', freq=None)] are in the [index]"

# %%
df_revenue=df_delta.mul(price.loc[df_delta.index],axis=0)
# Out:
# DatetimeIndex(['2010-01-01 01:00:00', '2010-01-01 02:00:00',
#                '2010-01-01 03:00:00', '2010-01-01 04:00:00',
#                '2010-01-01 05:00:00', '2010-01-01 06:00:00',
#                '2010-01-01 07:00:00', '2010-01-01 08:00:00',
#                '2010-01-01 09:00:00', '2010-01-01 10:00:00',
#                ...
#                '2017-12-31 15:00:00', '2017-12-31 16:00:00',
#                '2017-12-31 17:00:00', '2017-12-31 18:00:00',
#                '2017-12-31 19:00:00', '2017-12-31 20:00:00',
#                '2017-12-31 21:00:00', '2017-12-31 22:00:00',
#                '2017-12-31 23:00:00', '2018-01-01 00:00:00'],
#               dtype='datetime64[ns]', name=u'SETTLEMENTDATE', length=70608, freq=None)

# %%
price
# Out:
# SETTLEMENTDATE
# 2010-01-01 01:00:00     19.95
# 2010-01-01 02:00:00     17.48
# 2010-01-01 03:00:00     15.12
# 2010-01-01 04:00:00     11.35
# 2010-01-01 05:00:00     12.93
# 2010-01-01 06:00:00     12.86
# 2010-01-01 07:00:00     14.20
# 2010-01-01 08:00:00     16.84
# 2010-01-01 09:00:00     18.35
# 2010-01-01 10:00:00     19.52
# 2010-01-01 11:00:00     19.67
# 2010-01-01 12:00:00     20.07
# 2010-01-01 13:00:00     19.60
# 2010-01-01 14:00:00     18.94
# 2010-01-01 15:00:00     19.04
# 2010-01-01 16:00:00     19.52
# 2010-01-01 17:00:00     21.01
# 2010-01-01 18:00:00     22.38
# 2010-01-01 19:00:00     20.09
# 2010-01-01 20:00:00     19.41
# 2010-01-01 21:00:00     19.44
# 2010-01-01 22:00:00     17.66
# 2010-01-01 23:00:00     10.32
# 2010-01-02 00:00:00     17.53
# 2010-01-02 01:00:00     11.69
# 2010-01-02 02:00:00     11.84
# 2010-01-02 03:00:00      9.64
# 2010-01-02 04:00:00      8.63
# 2010-01-02 05:00:00      5.68
# 2010-01-02 06:00:00      9.07
#                         ...
# 2017-12-30 18:30:00     93.78
# 2017-12-30 19:30:00     71.69
# 2017-12-30 20:30:00     98.04
# 2017-12-30 21:30:00    101.05
# 2017-12-30 22:30:00     96.24
# 2017-12-30 23:30:00     65.42
# 2017-12-31 00:30:00     83.65
# 2017-12-31 01:30:00     86.43
# 2017-12-31 02:30:00     84.72
# 2017-12-31 03:30:00     68.90
# 2017-12-31 04:30:00     80.47
# 2017-12-31 05:30:00    108.11
# 2017-12-31 06:30:00     83.93
# 2017-12-31 07:30:00    107.26
# 2017-12-31 08:30:00    120.33
# 2017-12-31 09:30:00    127.49
# 2017-12-31 10:30:00    172.13
# 2017-12-31 11:30:00    129.46
# 2017-12-31 12:30:00    131.46
# 2017-12-31 13:30:00    244.10
# 2017-12-31 14:30:00    137.44
# 2017-12-31 15:30:00    111.32
# 2017-12-31 16:30:00    105.13
# 2017-12-31 17:30:00     99.36
# 2017-12-31 18:30:00    109.57
# 2017-12-31 19:30:00     95.19
# 2017-12-31 20:30:00    101.04
# 2017-12-31 21:30:00    105.44
# 2017-12-31 22:30:00    103.59
# 2017-12-31 23:30:00    112.75
# Name: SA, Length: 70127, dtype: float64

# %%
import ancil_graph
import ancil_load
import pandas as pd
ancil_graph=reload(ancil_graph)
ancil_load=reload(ancil_load)

# %%
# STEP1 MST maker

# base file name
basefn="/mnt/y/Data/Weather/ECMWF/Data_R/ml/{0}/{1:02d}/era5_hourly_ml_AUS_{0}{1:02d}.nc"

# loop over all extreme times
for i,tm in enumerate(filtered_times):

    tstart=tm - dt.timedelta(days=1)
    tstart2=tm + dt.timedelta(days=1)

    year  =  tm.year
    month =  tm.month
    day   =  tm.day
    hour  =  tm.hour
    rrp   =  fprice[i]

    # saving plots here
    outpath="/mnt/y/Code/Analysis/graph/Graph_figures/EVENTbased/South Australia"

    # load generators
#     df_all = pd.read_csv("/mnt/y/Data/Power/ECMWF/lillypond/future_wind.csv")
#     df_all=df_all.drop("time",axis=1)
#     df_all=df_all.drop("Unnamed: 0",axis=1)
#     df_all=df_all.iloc[1:,:]
#     # the 2016-01-2 -> 2016-01-3 missing behaving going to 2016-02-02 instead so hard code dates!
#     df_all.index=pd.date_range(start=dt.datetime(2008,1,1,1),end=dt.datetime(2017,12,31,23),freq="h")

    # load generators (as above)! --- > SA wind

    # Munge creates MST plot
    # works
    #df_delta,df_revenue,G = ancil_load.munge_MST(tstart,tstart2,df_all,fprice,outpath+"MST/size_prod_color_VF_{0}_{1}.png".format(tstart,tstart2))
    # NOt tested
    df_delta,df_revenue,G = ancil_load.munge_MST(tstart,tstart2,df_all,price,outpath+"MST/size_prod_color_VF_{0}_{1}.png".format(tstart,tstart2))

    
    # STEP2 analytics.
    import matplotlib.pyplot as plt
    
    # Calculate dataframe of Analytics
    df_central=ancil_load.munge_analytics_MST(G,tstart)

    import seaborn as sns

    f=plt.figure(figsize=(20,10))
    f=sns.lmplot(data=df_central,x="ValueFactor",y="Degree_centrality",hue="node",fit_reg=False)
    f.savefig(outpath+"Degree_centrality/"+"degree_{0}{1:02d}{2:02d}_{3}_RRP_{4}.png".format(year,month,day,hour,rrp))

    
    f=plt.figure(figsize=(20,10))
    f=sns.lmplot(data=df_central,x="ValueFactor",y="CBN1",hue="node",fit_reg=False)
    f.savefig(outpath+"CBN1/"+"CBN1_{0}{1:02d}{2:02d}_{3}_RRP_{4}.png".format(year,month,day,hour,rrp))


    f=plt.figure(figsize=(20,10))
    f=sns.lmplot(data=df_central,x="ValueFactor",y="CBN2",hue="node",fit_reg=False)
    f.savefig(outpath+"CBN2/"+"CBN2_{0}{1:02d}{2:02d}_{3}_RRP_{4}.png".format(year,month,day,hour,rrp))


    f=plt.figure(figsize=(20,10))
    f=sns.lmplot(data=df_central,x="ValueFactor",y="CBN3",hue="node",fit_reg=False)
    f.savefig(outpath+"CBN3/"+"CBN3_{0}{1:02d}{2:02d}_{3}_RRP_{4}.png".format(year,month,day,hour,rrp))
    plt.clf()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-89-19501b8335c7> in <module>()
#      33     #df_delta,df_revenue,G = ancil_load.munge_MST(tstart,tstart2,df_all,fprice,outpath+"MST/size_prod_color_VF_{0}_{1}.png".format(tstart,tstart2))
#      34     # NOt tested
# ---> 35     df_delta,df_revenue,G = ancil_load.munge_MST(tstart,tstart2,df_all,price,outpath+"MST/size_prod_color_VF_{0}_{1}.png".format(tstart,tstart2))
#      36
#      37
#
# /mnt/y/Code/Analysis/graph/ancil_load.pyc in munge_MST(tstart, tstart2, df_all, price, out)
#     285
#     286     df_delta = df_all.loc[tstart:tstart2]
# --> 287     df_revenue=df_delta.mul(price.loc[df_delta.index],axis=0)
#     288     G=ancil_graph.makeG1(df_delta,df_revenue,price.loc[df_delta.index],out)
#     289
#
# /home/peterad/.local/lib/python2.7/site-packages/pandas/core/indexing.pyc in __getitem__(self, key)
#    1371
#    1372             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1373             return self._getitem_axis(maybe_callable, axis=axis)
#    1374
#    1375     def _is_scalar_access(self, key):
#
# /home/peterad/.local/lib/python2.7/site-packages/pandas/core/indexing.pyc in _getitem_axis(self, key, axis)
#    1614                     raise ValueError('Cannot index with multidimensional key')
#    1615
# -> 1616                 return self._getitem_iterable(key, axis=axis)
#    1617
#    1618             # nested tuple slicing
#
# /home/peterad/.local/lib/python2.7/site-packages/pandas/core/indexing.pyc in _getitem_iterable(self, key, axis)
#    1113
#    1114         if self._should_validate_iterable(axis):
# -> 1115             self._has_valid_type(key, axis)
#    1116
#    1117         labels = self.obj._get_axis(axis)
#
# /home/peterad/.local/lib/python2.7/site-packages/pandas/core/indexing.pyc in _has_valid_type(self, key, axis)
#    1470                         raise KeyError(
#    1471                             u"None of [{key}] are in the [{axis}]".format(
# -> 1472                                 key=key, axis=self.obj._get_axis_name(axis)))
#    1473                     else:
#    1474
#
# KeyError: u"None of [DatetimeIndex(['2017-01-03 16:00:00', '2017-01-03 17:00:00',\n               '2017-01-03 18:00:00', '2017-01-03 19:00:00',\n               '2017-01-03 20:00:00', '2017-01-03 21:00:00',\n               '2017-01-03 22:00:00', '2017-01-03 23:00:00',\n               '2017-01-04 00:00:00', '2017-01-04 01:00:00',\n               '2017-01-04 02:00:00', '2017-01-04 03:00:00',\n               '2017-01-04 04:00:00', '2017-01-04 05:00:00',\n               '2017-01-04 06:00:00', '2017-01-04 07:00:00',\n               '2017-01-04 08:00:00', '2017-01-04 09:00:00',\n               '2017-01-04 10:00:00', '2017-01-04 11:00:00',\n               '2017-01-04 12:00:00', '2017-01-04 13:00:00',\n               '2017-01-04 14:00:00', '2017-01-04 15:00:00',\n               '2017-01-04 16:00:00', '2017-01-04 17:00:00',\n               '2017-01-04 18:00:00', '2017-01-04 19:00:00',\n               '2017-01-04 20:00:00', '2017-01-04 21:00:00',\n               '2017-01-04 22:00:00', '2017-01-04 23:00:00',\n               '2017-01-05 00:00:00', '2017-01-05 01:00:00',\n               '2017-01-05 02:00:00', '2017-01-05 03:00:00',\n               '2017-01-05 04:00:00', '2017-01-05 05:00:00',\n               '2017-01-05 06:00:00', '2017-01-05 07:00:00',\n               '2017-01-05 08:00:00', '2017-01-05 09:00:00',\n               '2017-01-05 10:00:00', '2017-01-05 11:00:00',\n               '2017-01-05 12:00:00', '2017-01-05 13:00:00',\n               '2017-01-05 14:00:00', '2017-01-05 15:00:00'],\n              dtype='datetime64[ns]', name=u'SETTLEMENTDATE', freq=None)] are in the [index]"

# %%
import seaborn as sns
# Degree_centrlaity
a=sns.lmplot(data=df_central,x="ValueFactor",y="Degree_centrality",hue="node",fit_reg=False)
#df.plot.bar(x="node",y="katz")

# %% [markdown]
# ### 2. Wind and TEMP

# %%
tm
# Out:
# Timestamp('2017-01-09 13:00:00')

# %%
rrp
# Out:
# 109.74

# %%
f.

# %%
# wind base name
basefn="/mnt/y/Data/Weather/ECMWF/Data_R/ml/{0}/{1:02d}/era5_hourly_ml_AUS_{0}{1:02d}.nc"

for i,tm in enumerate(price.index):
    ancil_load.Cartopy_Earth_wind(tm,"t",price[i],basefn)
# Out:
# /mnt/y/Code/Analysis/graph/ancil_load.py:423: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/usr/lib/python2.7/runpy.py", line 174, in _run_module_as_main
#     "__main__", fname, loader, pkg_name)
#   File "/usr/lib/python2.7/runpy.py", line 72, in _run_code
#     exec code in run_globals
#   File "/home/peterad/.local/lib/python2.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/peterad/.local/lib/python2.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/peterad/.local/lib/python2.7/site-packages/ipykernel/kernelapp.py", line 486, in start
#     self.io_loop.start()
#   File "/home/peterad/.local/lib/python2.7/site-packages/tornado/ioloop.py", line 1064, in start
#     handler_func(fd_obj, events)
#   File "/home/peterad/.local/lib/python2.7/site-packages/tornado/stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/peterad/.local/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/home/peterad/.local/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/home/peterad/.local/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/home/peterad/.local/lib/python2.7/site-packages/tornado/stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/peterad/.local/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/home/peterad/.local/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/home/peterad/.local/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/home/peterad/.local/lib/python2.7/site-packages/ipykernel/ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/peterad/.local/lib/python2.7/site-packages/ipykernel/zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/peterad/.local/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2724, in run_cell
#     self.events.trigger('post_run_cell')
#   File "/home/peterad/.local/lib/python2.7/site-packages/IPython/core/events.py", line 74, in trigger
#     func(*args, **kwargs)
#   File "/home/peterad/.local/lib/python2.7/site-packages/ipykernel/pylab/backend_inline.py", line 160, in configure_once
#     activate_matplotlib(backend)
#   File "/home/peterad/.local/lib/python2.7/site-packages/IPython/core/pylabtools.py", line 312, in activate_matplotlib
#     matplotlib.pyplot.switch_backend(backend)
#   File "/home/peterad/.local/lib/python2.7/site-packages/matplotlib/pyplot.py", line 231, in switch_backend
#     matplotlib.use(newbackend, warn=False, force=True)
#   File "/home/peterad/.local/lib/python2.7/site-packages/matplotlib/__init__.py", line 1410, in use
#     reload(sys.modules['matplotlib.backends'])
#   File "/home/peterad/.local/lib/python2.7/site-packages/matplotlib/backends/__init__.py", line 16, in <module>
#     line for line in traceback.format_stack()
#
#
#   matplotlib.use('Agg') #https://stackoverflow.com/questions/37604289/tkinter-tclerror-no-display-name-and-no-display-environment-variable
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-13-f9fc63f2df58> in <module>()
#       3
#       4 for i,tm in enumerate(price.index):
# ----> 5     ancil_load.Cartopy_Earth_wind(tm,"t",price[i],basefn)
#
# /mnt/y/Code/Analysis/graph/ancil_load.py in Cartopy_Earth_wind(tm, var, rrp, basefn)
#     427     import numpy as np
#     428     from matplotlib import cm
# --> 429     import cartopy.crs as ccrs
#     430     import pandas as pd
#     431     import sys
#
# /mnt/y/Code/Analysis/graph/powerdeck/cartopy.py in <module>()
#       3
#       4 from datetime import datetime
# ----> 5 import cartopy.crs as ccrs
#       6 import cartopy.feature as cfeature
#       7 import matplotlib.pyplot as plt
#
# ImportError: No module named crs

# %% [markdown]
# ### 3. TEMP

# %% [markdown]
# ## PPTX

# %%
from netCDF4 import Dataset, MFDataset, num2date
import matplotlib.pylab as plt
import numpy as np
from matplotlib import cm
import cartopy.crs as ccrs

import sys
import os
from cartopy.util import add_cyclic_point

# The hard part!
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-5-cd2028b585a3> in <module>()
#       3 import numpy as np
#       4 from matplotlib import cm
# ----> 5 import cartopy.crs as ccrs
#       6
#       7 import sys
#
# /mnt/y/Code/Analysis/graph/powerdeck/cartopy.py in <module>()
#       3
#       4 from datetime import datetime
# ----> 5 import cartopy.crs as ccrs
#       6 import cartopy.feature as cfeature
#       7 import matplotlib.pyplot as plt
#
# ImportError: No module named crs

# %%
x35*8*4*48
# Out:
# 53760
