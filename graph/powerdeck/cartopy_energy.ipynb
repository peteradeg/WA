# %%
import pandas as pd

# %%
pd.read_csv("/mnt/y/Data/Electricity/Average_prices/df_all_Aust_PUBLIC_DVD_TRADING_PRICE.csv")
# Out:
#              SETTLEMENTDATE  AGLHAL  AGLSOM  ANGAS1  ANGAS2  ANGAST1  APD01  \
# 0       2010-01-01 00:30:00     0.0     0.0     0.0     0.0      NaN    0.0
# 1       2010-01-01 01:00:00     0.0     0.0     0.0     0.0      NaN    0.0
# 2       2010-01-01 01:30:00     0.0     0.0     0.0     0.0      NaN    0.0
# 3       2010-01-01 02:00:00     0.0     0.0     0.0     0.0      NaN    0.0
# 4       2010-01-01 02:30:00     0.0     0.0     0.0     0.0      NaN    0.0
# 5       2010-01-01 03:00:00     0.0     0.0     0.0     0.0      NaN    0.0
# 6       2010-01-01 03:30:00     0.0     0.0     0.0     0.0      NaN    0.0
# 7       2010-01-01 04:00:00     0.0     0.0     0.0     0.0      NaN    0.0
# 8       2010-01-01 04:30:00     0.0     0.0     0.0     0.0      NaN    0.0
# 9       2010-01-01 05:00:00     0.0     0.0     0.0     0.0      NaN    0.0
# 10      2010-01-01 05:30:00     0.0     0.0     0.0     0.0      NaN    0.0
# ...
